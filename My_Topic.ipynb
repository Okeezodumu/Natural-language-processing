# %% [markdown]
# <a href="https://colab.research.google.com/github/Okeezodumu/Natural-language-processing/blob/main/My_Topic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Topic modelling assignment
# Assignment: Topic Modeling COVID-19 Research Titles
# Problem Statement:
# Identifying recurring themes in COVID-19 research can be overwhelming due to the large volume of studies. In this assignment, you will use BERTopic to analyze research paper titles and uncover key topics in the field.
#
# Steps:
# Dataset Overview:
#
# Use the provided dataset containing research titles, abstracts, and URLs.
# Focus only on the titles column for topic modeling.
# Objective:
#
# Apply BERTopic to discover and analyze topics in the research titles.
# Tasks:
#
#
# Analysis:
# Extract and list the topics with their top keywords.
# Visualize topic distributions.
# Identify the most common topic and summarize its significance.
# Assign a topic and topic name to every title in dataset.
#
# Deliverables:
# A Python script implementing BERTopic.
# A brief summary (150–200 words) discussing key findings and visualizations.

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.4-py3-none-any.whl.metadata (23 kB)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.40-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.0)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (3.3.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.47.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.1.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.12.14)
# Downloading bertopic-0.16.4-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 6.0 MB/s eta 0:00:00
# Downloading hdbscan-0.8.40-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 52.2 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 7.1 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: pynndescent, hdbscan, umap-learn, bertopic
# Successfully installed bertopic-0.16.4 hdbscan-0.8.40 pynndescent-0.5.13 umap-learn-0.5.7

# %%
import pandas as pd
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer, util
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer

# %%
df=pd.read_csv('/content/covid_abstracts.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  Real-World Experience with COVID-19  Including...
# 1  Successful outcome of pre-engraftment COVID-19...
# 2  The impact of COVID-19 on oncology professiona...
# 3  ICU admission and mortality classifiers for CO...
# 4  Clinical evaluation of nasopharyngeal  midturb...
#
#                                             abstract  \
# 0  This article summarizes the experiences of COV...
# 1  Coronavirus disease 2019  COVID-19   caused by...
# 2  BACKGROUND  COVID-19 has had a significant imp...
# 3  The coronavirus disease 2019  COVID-19  which ...
# 4  In the setting of supply chain shortages of na...
#
#                                         url
# 0  https://pubmed.ncbi.nlm.nih.gov/35008137
# 1  https://pubmed.ncbi.nlm.nih.gov/35008104
# 2  https://pubmed.ncbi.nlm.nih.gov/35007996
# 3  https://pubmed.ncbi.nlm.nih.gov/35007991
# 4  https://pubmed.ncbi.nlm.nih.gov/35007959

# %%
df=df.dropna()
print(df.shape)
# Out:
# (10000, 3)

# %%
df['title']=df['title'].astype(str)

# %%
#create an array of descriptions
doc = df.title.values

# %%
doc[0:5]
# Out:
# array(['Real-World Experience with COVID-19  Including Direct COVID-19 Antigen Testing and Monoclonal-Antibody Bamlanivimab in a Rural Critical Access Hospital in South Dakota',
#        'Successful outcome of pre-engraftment COVID-19 in an HCT patient  impact of targeted therapies and cellular immunity',
#        'The impact of COVID-19 on oncology professionals-one year on  lessons learned from the ESMO Resilience Task Force survey series',
#        'ICU admission and mortality classifiers for COVID-19 patients based on subgroups of dynamically associated profiles across multiple timepoints',
#        'Clinical evaluation of nasopharyngeal  midturbinate nasal and oropharyngeal swabs for the detection of SARS-CoV-2'],
#       dtype=object)

# %%
# Import the SentenceTransformer model to generate dense vector embeddings for documents
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")  # A pre-trained transformer model optimized for semantic similarity
#https://huggingface.co/sentence-transformers


# Instantiate the BERTopic model
# embedding_model: Specifies the embedding model to use for document vectorization.
# language: Defines the language of the documents (in this case, English).
# calculate_probabilities: Indicates whether to calculate the probabilities of a document belonging to topics (True).
# verbose: Enables detailed logging of the model's processing steps for better visibility.
topic_model = BERTopic(
    embedding_model=embedding_model,
    language="english",
    calculate_probabilities=True,
    verbose=True
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Generate topics and their corresponding probabilities for the documents
# topics: A list of integers, where each integer corresponds to the topic assigned to a specific document.
# probs: A 2D array (list of lists), where each inner list contains the probabilities of the corresponding document
#        belonging to each topic.
topics, probs = topic_model.fit_transform(doc)  # doc is a list of input documents to be analyzed
# Out:
# 2025-01-22 13:28:51,940 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# 2025-01-22 13:31:41,239 - BERTopic - Embedding - Completed ✓
# 2025-01-22 13:31:41,243 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-01-22 13:32:31,159 - BERTopic - Dimensionality - Completed ✓
# 2025-01-22 13:32:31,164 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-01-22 13:32:47,571 - BERTopic - Cluster - Completed ✓
# 2025-01-22 13:32:47,587 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2025-01-22 13:32:47,976 - BERTopic - Representation - Completed ✓

# %%
len(probs)
# Out:
# 10000

# %%
topic_model.get_topic(0)
# Out:
# [('telemedicine', 0.06820603187670492),
#  ('telehealth', 0.054182497844639514),
#  ('satisfaction', 0.016862541257429448),
#  ('during', 0.013048094244910918),
#  ('program', 0.011606459591798254),
#  ('use', 0.011043707870705173),
#  ('pandemic', 0.010405387979726791),
#  ('pediatric', 0.01036672462295814),
#  ('epilepsy', 0.010121382476508609),
#  ('patient', 0.010010090531074727)]

# %%
topic_model.get_topic(13)
# Out:
# [('masks', 0.06879780480001729),
#  ('mask', 0.062123570190341),
#  ('face', 0.05706986492443266),
#  ('wearing', 0.04542509585563421),
#  ('n95', 0.029196988038491665),
#  ('respirators', 0.027824085810045886),
#  ('aerosol', 0.024226717789671576),
#  ('surgical', 0.023827546724885722),
#  ('fit', 0.020429028599878236),
#  ('respirator', 0.016738589571778435)]

# %%
topic_model.get_topic_info() #show topic information
# Out:
#      Topic  Count                                               Name  \
# 0       -1   3568                                 -1_the_of_covid_19
# 1        0    164      0_telemedicine_telehealth_satisfaction_during
# 2        1    155                1_mental_health_psychiatric_workers
# 3        2    144         2_respiratory_oxygen_ventilation_pulmonary
# 4        3    131               3_drug_treatment_potential_antiviral
# ..     ...    ...                                                ...
# 176    175     10               175_distancing_social_kalman_regimes
# 177    176     10         176_employment_benefits_unemployment_loans
# 178    177     10  177_coagulopathy_fibrinogen_coagulation_intrav...
# 179    178     10             178_metabolic_adiposity_lipid_severity
# 180    179     10               179_migrant_refugees_migrants_asylum
#
#                                         Representation  \
# 0    [the, of, covid, 19, in, and, to, cov, pandemi...
# 1    [telemedicine, telehealth, satisfaction, durin...
# 2    [mental, health, psychiatric, workers, work, p...
# 3    [respiratory, oxygen, ventilation, pulmonary, ...
# 4    [drug, treatment, potential, antiviral, therap...
# ..                                                 ...
# 176  [distancing, social, kalman, regimes, mali, ev...
# 177  [employment, benefits, unemployment, loans, em...
# 178  [coagulopathy, fibrinogen, coagulation, intrav...
# 179  [metabolic, adiposity, lipid, severity, secret...
# 180  [migrant, refugees, migrants, asylum, receptio...
#
#                                    Representative_Docs
# 0    [Psychological Impact of the COVID-19 Pandemic...
# 1    [Development of a Telemedicine Screening Progr...
# 2    [The mental health impact of contact with COVI...
# 3    [High-flow nasal oxygen therapy decrease the r...
# 4    [Antiviral drugs   Potent agents  promising th...
# ..                                                 ...
# 176  [Effectiveness of social distancing interventi...
# 177  [This time is really different  The multiplier...
# 178  [Investigation of the Molecular Mechanism of C...
# 179  [The risk factor for instability metabolic hea...
# 180  [It is a disease which comes and kills directl...
#
# [181 rows x 5 columns]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d39b2041-5e99-4a37-aac7-d754a42aec99" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d39b2041-5e99-4a37-aac7-d754a42aec99")) {                    Plotly.newPlot(                        "d39b2041-5e99-4a37-aac7-d754a42aec99",                        [{"customdata":[[0,"telemedicine | telehealth | satisfaction | during | program",164],[1,"mental | health | psychiatric | workers | work",155],[2,"respiratory | oxygen | ventilation | pulmonary | mechanical",144],[3,"drug | treatment | potential | antiviral | therapeutic",131],[4,"child | children | parents | families | mental",126],[5,"sars | cov | transmission | workers | infection",116],[6,"protease | inhibitors | main | silico | vitro",114],[7,"variants | sars | cov | against | vaccine",105],[8,"online | learning | education | teaching | students",104],[9,"antibodies | igg | neutralizing | antibody | sars",103],[10,"spike | ace2 | protein | binding | receptor",102],[11,"media | twitter | social | news | information",101],[12,"prognosis | reactive | meta | systematic | clinical",88],[13,"masks | mask | face | wearing | n95",82],[14,"nurses | nursing | nurse | qualitative | experiences",81],[15,"vaccine | vaccination | 2021 | effectiveness | vaccines",75],[16,"pregnant | pregnancy | women | neonatal | maternal",74],[17,"graphene | detection | biosensor | electrochemical | based",73],[18,"modeling | mathematical | epidemic | model | dynamics",71],[19,"vaccine | willingness | acceptance | hesitancy | uptake",67],[20,"images | ray | chest | deep | ct",66],[21,"dental | oral | dentistry | dentists | dysphagia",66],[22,"neurological | brain | palsy | nerve | report",64],[23,"cytokine | neutrophil | storm | cytokines | monocyte",61],[24,"machine | artificial | intelligence | learning | algorithms",59],[25,"sleep | quality | insomnia | circadian | anxiety",59],[26,"mobility | transport | transportation | spatial | data",58],[27,"respiratory | syndrome | acute | coronavirus | severe",57],[28,"pollution | air | pm2 | lockdown | organic",57],[29,"students | university | college | academic | being",54],[30,"lessons | emergency | response | crisis | casualty",52],[31,"mortality | excess | deaths | brazil | 2020",52],[32,"sequencing | genome | mutations | genomic | mutation",52],[33,"transplant | recipients | kidney | hemodialysis | solid",52],[34,"multisystem | inflammatory | syndrome | mis | appendicitis",52],[35,"workers | healthcare | frontline | work | occupational",51],[36,"saudi | arabia | pakistan | stigma | curfew",51],[37,"trauma | hip | fracture | fractures | knee",50],[38,"pediatric | children | pediatrics | mis | paediatric",48],[39,"cell | cells | memory | specific | cd4",47],[40,"2019 | coronavirus | disease | corona | clinical",47],[41,"retinal | eye | ocular | optic | corneal",46],[42,"digital | record | data | health | transformation",46],[43,"thrombocytopenia | thrombosis | thrombotic | venous | sinus",45],[44,"eating | nutritional | diet | nervosa | habits",45],[45,"food | insecurity | security | assistance | meat",41],[46,"surgery | surgical | elective | training | learnt",40],[47,"children | cov | sars | infection | pediatric",40],[48,"bowel | inflammatory | microbiota | gut | ibd",39],[49,"postpartum | women | pregnant | anxiety | maternal",38],[50,"bnt162b2 | mrna | vaccine | immunogenicity | after",38],[51,"mucormycosis | rhino | orbital | cerebral | orbito",37],[52,"pcr | rt | pooled | test | testing",37],[53,"pneumonia | classification | pneumonias | biofilm | pneumocystis",36],[54,"china | epidemiological | control | prevention | epidemic",36],[55,"knowledge | attitude | practices | attitudes | toward",36],[56,"india | blood | tertiary | monsoon | newer",36 ...

# %%
topic_model.visualize_barchart(top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="beab423c-658f-4d86-b153-dec9ab338f66" class="plotly-graph-div" style="height:1250px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("beab423c-658f-4d86-b153-dec9ab338f66")) {                    Plotly.newPlot(                        "beab423c-658f-4d86-b153-dec9ab338f66",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.011606459591798254,0.013048094244910918,0.016862541257429448,0.054182497844639514,0.06820603187670492],"y":["program  ","during  ","satisfaction  ","telehealth  ","telemedicine  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.017147619735389908,0.01744015163177293,0.01917662850570831,0.024070492793351137,0.04298460760309726],"y":["work  ","workers  ","psychiatric  ","health  ","mental  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02232076014895263,0.02493276037587117,0.027103780180871048,0.030116827065986156,0.03213363648664241],"y":["mechanical  ","pulmonary  ","ventilation  ","oxygen  ","respiratory  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.020584078291965482,0.02457546358326977,0.02483526532347156,0.026804848062915956,0.02740947509157805],"y":["therapeutic  ","antiviral  ","potential  ","treatment  ","drug  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.022636174810059112,0.02281453074893892,0.02510809656818561,0.03536276235493206,0.03904951240199718],"y":["mental  ","families  ","parents  ","children  ","child  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.014112230471863812,0.016030378463815574,0.01907692513985602,0.022240937152699453,0.0227494999147973],"y":["infection  ","workers  ","transmission  ","cov  ","sars  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.027688544834202206,0.03488197223319504,0.03947328990069036,0.054848800825854895,0.06027019865646176],"y":["vitro  ","silico  ","main  ","inhibitors  ","protease  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.022466640495430623,0.0227218964739568,0.024945007979870964,0.025359432034275032,0.028339617854041294],"y":["vaccine  ","against  ","cov  ","sars  ","variants  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.034882357714064775,0.0353907127927616,0.04016369615218811,0.04850700191591136,0.051437925964263935],"y":["students  ","teaching  ","education  ","learning  ","online  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.026099434233895366,0.03257720959006508,0.03643402407239463,0.038349012942847295,0.058389663531571837],"y":["sars  ","antibody  ","neutralizing  ","igg  ","antibodies  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.033132919495365454,0.0456345667908556,0.05404949764136082,0.0548479561466403,0.08760409831446997],"y":["receptor  ","binding  ","protein  ","ace2  ","spike  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.029281636943194835,0.03362095535913848,0.04262360937744843,0.04379847452459692,0.06980111815674125],"y":["information  ","news  ","social  ","twitter  ","media  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.015957510653439207,0.017348030199261316,0.017651954504155194,0.0185480149752612,0.019454499102206396],"y":["clinical  ","systematic  ","meta  ","reactive  ","prognosis  "],"type":"bar","xaxis":"x13","yaxis":"y13 ...

# %%
topic_model.visualize_heatmap( width=1000, height=1000)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="65ab64fa-84fe-4c04-8c6a-5f02a2af6a21" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65ab64fa-84fe-4c04-8c6a-5f02a2af6a21")) {                    Plotly.newPlot(                        "65ab64fa-84fe-4c04-8c6a-5f02a2af6a21",                        [{"coloraxis":"coloraxis","name":"0","x":["0_telemedicine_telehealth_s...","1_mental_health_psychiatric","2_respiratory_oxygen_ventil...","3_drug_treatment_potential","4_child_children_parents","5_sars_cov_transmission","6_protease_inhibitors_main","7_variants_sars_cov","8_online_learning_education","9_antibodies_igg_neutralizing","10_spike_ace2_protein","11_media_twitter_social","12_prognosis_reactive_meta","13_masks_mask_face","14_nurses_nursing_nurse","15_vaccine_vaccination_2021","16_pregnant_pregnancy_women","17_graphene_detection_biose...","18_modeling_mathematical_ep...","19_vaccine_willingness_acce...","20_images_ray_chest","21_dental_oral_dentistry","22_neurological_brain_palsy","23_cytokine_neutrophil_storm","24_machine_artificial_intel...","25_sleep_quality_insomnia","26_mobility_transport_trans...","27_respiratory_syndrome_acute","28_pollution_air_pm2","29_students_university_coll...","30_lessons_emergency_response","31_mortality_excess_deaths","32_sequencing_genome_mutati...","33_transplant_recipients_ki...","34_multisystem_inflammatory...","35_workers_healthcare_front...","36_saudi_arabia_pakistan","37_trauma_hip_fracture","38_pediatric_children_pedia...","39_cell_cells_memory","40_2019_coronavirus_disease","41_retinal_eye_ocular","42_digital_record_data","43_thrombocytopenia_thrombo...","44_eating_nutritional_diet","45_food_insecurity_security","46_surgery_surgical_elective","47_children_cov_sars","48_bowel_inflammatory_micro...","49_postpartum_women_pregnant","50_bnt162b2_mrna_vaccine","51_mucormycosis_rhino_orbital","52_pcr_rt_pooled","53_pneumonia_classification...","54_china_epidemiological_co...","55_knowledge_attitude_pract...","56_india_blood_tertiary","57_physical_activity_exercise","58_vaccines_delta_recombinant","59_aspergillosis_invasive_f...","60_vitamin_d3_status","61_loneliness_older_isolation","62_thrombosis_venous_thromb...","63_myocarditis_myopericardi...","64_skin_psoriasis_androgene...","65_dementia_caregivers_supp...","66_nanoparticles_delivery_n...","67_virtual_reality_skills","68_sclerosis_multiple_modif...","69_hearing_voice_audiology","70_pregnancy_maternal_fetal","71_stress_uncertainty_coping","72_monitoring_wearable_temp...","73_remdesivir_antiviral_syn...","74_cancer_colorectal_impact","75_diabetes_type_mellitus","76_transplant_recipients_ki...","77_stock_market_oil","78_omicron_variant_529","79_bioinformatics_atlas_drug","80_angiotensin_converting_e...","81_community_religious_sense","82_bnt162b2_mrna_humoral","83_opioid_poison_buprenorph...","84_kidney_injury_acute","85_host_replication_viral","86_myocardial_infarction_el...","87_health_policy_public","88_intensive_critically_ill","89_traumatic_posttraumatic_...","90_school_closures_schools","91_antibody_monoclonal_anti...","92_density_variants_cov","93_tourism_customer_consumer","94_alcohol_consumption_drin...","95_nursing_students_nurses","96_vaccines_mrna_anaphylaxis","97_asthma_allergic_inhaled","98_burnout_staff_stress","99_chile_mexico_prison","100_china_vaccine_uptake","101_football_professional_a...","102_scale_psychometric_anxi...","103_racial_disparities_ethnic","104_erectile_semen_men","105_hesitancy_vaccine_ethni...","106_resilience_healthcare_l...","107_tuberculosis_tb_endemic","108_cells_lung_epithelial","109_mortality_hospitalized_...","110_liver_cirrhosis_chronic","111_porous_surfaces_biodegr...","112_violence_intimate_partner","113_ultrasound_lung_pneumonia","11 ...

# %%
topic_model.generate_topic_labels()
# Out:
# ['-1_the_of_covid',
#  '0_telemedicine_telehealth_satisfaction',
#  '1_mental_health_psychiatric',
#  '2_respiratory_oxygen_ventilation',
#  '3_drug_treatment_potential',
#  '4_child_children_parents',
#  '5_sars_cov_transmission',
#  '6_protease_inhibitors_main',
#  '7_variants_sars_cov',
#  '8_online_learning_education',
#  '9_antibodies_igg_neutralizing',
#  '10_spike_ace2_protein',
#  '11_media_twitter_social',
#  '12_prognosis_reactive_meta',
#  '13_masks_mask_face',
#  '14_nurses_nursing_nurse',
#  '15_vaccine_vaccination_2021',
#  '16_pregnant_pregnancy_women',
#  '17_graphene_detection_biosensor',
#  '18_modeling_mathematical_epidemic',
#  '19_vaccine_willingness_acceptance',
#  '20_images_ray_chest',
#  '21_dental_oral_dentistry',
#  '22_neurological_brain_palsy',
#  '23_cytokine_neutrophil_storm',
#  '24_machine_artificial_intelligence',
#  '25_sleep_quality_insomnia',
#  '26_mobility_transport_transportation',
#  '27_respiratory_syndrome_acute',
#  '28_pollution_air_pm2',
#  '29_students_university_college',
#  '30_lessons_emergency_response',
#  '31_mortality_excess_deaths',
#  '32_sequencing_genome_mutations',
#  '33_transplant_recipients_kidney',
#  '34_multisystem_inflammatory_syndrome',
#  '35_workers_healthcare_frontline',
#  '36_saudi_arabia_pakistan',
#  '37_trauma_hip_fracture',
#  '38_pediatric_children_pediatrics',
#  '39_cell_cells_memory',
#  '40_2019_coronavirus_disease',
#  '41_retinal_eye_ocular',
#  '42_digital_record_data',
#  '43_thrombocytopenia_thrombosis_thrombotic',
#  '44_eating_nutritional_diet',
#  '45_food_insecurity_security',
#  '46_surgery_surgical_elective',
#  '47_children_cov_sars',
#  '48_bowel_inflammatory_microbiota',
#  '49_postpartum_women_pregnant',
#  '50_bnt162b2_mrna_vaccine',
#  '51_mucormycosis_rhino_orbital',
#  '52_pcr_rt_pooled',
#  '53_pneumonia_classification_pneumonias',
#  '54_china_epidemiological_control',
#  '55_knowledge_attitude_practices',
#  '56_india_blood_tertiary',
#  '57_physical_activity_exercise',
#  '58_vaccines_delta_recombinant',
#  '59_aspergillosis_invasive_fungal',
#  '60_vitamin_d3_status',
#  '61_loneliness_older_isolation',
#  '62_thrombosis_venous_thromboembolism',
#  '63_myocarditis_myopericarditis_mrna',
#  '64_skin_psoriasis_androgenetic',
#  '65_dementia_caregivers_support',
#  '66_nanoparticles_delivery_nanoparticle',
#  '67_virtual_reality_skills',
#  '68_sclerosis_multiple_modifying',
#  '69_hearing_voice_audiology',
#  '70_pregnancy_maternal_fetal',
#  '71_stress_uncertainty_coping',
#  '72_monitoring_wearable_temperature',
#  '73_remdesivir_antiviral_synthesis',
#  '74_cancer_colorectal_impact',
#  '75_diabetes_type_mellitus',
#  '76_transplant_recipients_kidney',
#  '77_stock_market_oil',
#  '78_omicron_variant_529',
#  '79_bioinformatics_atlas_drug',
#  '80_angiotensin_converting_enzyme',
#  '81_community_religious_sense',
#  '82_bnt162b2_mrna_humoral',
#  '83_opioid_poison_buprenorphine',
#  '84_kidney_injury_acute',
#  '85_host_replication_viral',
#  '86_myocardial_infarction_elevation',
#  '87_health_policy_public',
#  '88_intensive_critically_ill',
#  '89_traumatic_posttraumatic_ptsd',
#  '90_school_closures_schools',
#  '91_antibody_monoclonal_antibodies',
#  '92_density_variants_cov',
#  '93_tourism_customer_consumer',
#  '94_alcohol_consumption_drinking',
#  '95_nursing_students_nurses',
#  '96_vaccines_mrna_anaphylaxis',
#  '97_asthma_allergic_inhaled',
#  '98_burnout_staff_stress',
#  '99_chile_mexico_prison',
#  '100_china_vaccine_uptake',
#  '101_football_professional_athletes',
#  '102_scale_psychometric_anxiety',
#  '103_racial_disparities_ethnic',
#  '104_erectile_semen_men',
#  '105_hesitancy_vaccine_ethnicity',
#  '106_resilience_healthcare_lessons',
#  '107_tuberculosis_tb_endemic',
#  '108_cells_lung_epithelial',
#  '109_mortality_hospitalized_predictors',
#  '110_liver_cirrhosis_chronic',
#  '111_porous_surfaces_biodegradable',
#  '112_violence_intimate_partner',
#  '113_ultrasound_lung_pneumonia',
#  '114_adherence_guidelines_compliance',
#  '115_qpcr_rt_pcr',
#  '116_breast_cancer_hispanic',
#  '117_chest_ct_tomography',
#  '118_cost_screening_kenya',
#  '119_hiv_services_adherence',
#  '120_suicidal_suicide_ideation',
#  '121_arabia_saudi_hesitancy',
#  '122_rehabilitation_cardiac_physiotherapists',
#  '123_cardiovascular_heart_prognosis',
#  '124_plasma_convalescent_controlled',
#  '125_mathematics_education_mathematical',
#  '126_pneumothorax_spontaneous_pneumomediastinum',
#  '127_tracing_contact_san',
#  '128_substance_use_addictive',
#  '129_cats_dogs_domestic',
#  '130_saliva_salivary_swabs',
#  '131_stroke_ischemic_mena',
#  '132_smoking_tobacco_smokers',
#  '133_france_vaccination_spain',
#  '134_pain_fibromyalgia_chronic',
#  '135_wastewater_surveillance_sewage',
#  '136_omicron_529_neutralizing',
#  '137_weight_obesity_lifestyle',
#  '138_hemodialysis_dialysis_haemodialysis',
#  '139_virtual_diabetes_oncology',
#  '140_isothermal_amplification_loop',
#  '141_resuscitation_cardiopulmonary_cardiac',
#  '142_hiv_people_living',
#  '143_multisystem_inflammatory_syndrome',
#  '144_chadox1_ncov_azd1222',
#  '145_parkinson_motor_feasibility',
#  '146_corticosteroids_corticosteroid_systemic',
#  '147_internet_addiction_adolescents',
#  '148_immune_sex_aging',
#  '149_capacity_icu_simulation',
#  '150_cystic_fibrosis_telehealth',
#  '151_influenza_united_kingdom',
#  '152_urban_cities_green',
#  '153_depression_anxiety_probable',
#  '154_disinfection_surfaces_bacterial',
#  '155_dementia_cognitive_20',
#  '156_extracorporeal_oxygenation_membrane',
#  '157_tocilizumab_pneumonia_steroid',
#  '158_tracheostomy_tracheal_timing',
#  '159_reproductive_sexual_sex',
#  '160_pharmacists_pharmacist_pharmacy',
#  '161_telerehabilitation_effectiveness_feasibility',
#  '162_fatigue_carnitine_mendelian',
#  '163_palliative_care_end',
#  '164_axillary_pet_fdg',
#  '165_heart_failure_cardiovascular',
#  '166_arthritis_rheumatoid_rheumatic',
#  '167_industries_economies_trade',
#  '168_mesenchymal_stem_cells',
#  '169_hypertension_pressure_control',
#  '170_mrna_revolution_development',
#  '171_hand_hygiene_hospitals',
#  '172_pandemics_science_climate',
#  '173_embolism_pulmonary_dimers',
#  '174_deep_learning_entity',
#  '175_distancing_social_kalman',
#  '176_employment_benefits_unemployment',
#  '177_coagulopathy_fibrinogen_coagulation',
#  '178_metabolic_adiposity_lipid',
#  '179_migrant_refugees_migrants']

# %%
topic_model.find_topics("vaccine") # topic 0,15 19, 58 ,96,97,100,171.172 relate with COVID-19
# Out:
# ([96, 58, 15, 19, 105],
#  [0.6674495, 0.65018547, 0.64887655, 0.6286167, 0.6200327])

# %%
df.head()
# Out:
#                                                title  \
# 0  Real-World Experience with COVID-19  Including...
# 1  Successful outcome of pre-engraftment COVID-19...
# 2  The impact of COVID-19 on oncology professiona...
# 3  ICU admission and mortality classifiers for CO...
# 4  Clinical evaluation of nasopharyngeal  midturb...
#
#                                             abstract  \
# 0  This article summarizes the experiences of COV...
# 1  Coronavirus disease 2019  COVID-19   caused by...
# 2  BACKGROUND  COVID-19 has had a significant imp...
# 3  The coronavirus disease 2019  COVID-19  which ...
# 4  In the setting of supply chain shortages of na...
#
#                                         url
# 0  https://pubmed.ncbi.nlm.nih.gov/35008137
# 1  https://pubmed.ncbi.nlm.nih.gov/35008104
# 2  https://pubmed.ncbi.nlm.nih.gov/35007996
# 3  https://pubmed.ncbi.nlm.nih.gov/35007991
# 4  https://pubmed.ncbi.nlm.nih.gov/35007959

# %%
# Step 1: Assign topic numbers to the DataFrame
df["topic"] = topics  # The `topics` output from BERTopic

df.head(10)
# Out:
#                                                title  \
# 0  Real-World Experience with COVID-19  Including...
# 1  Successful outcome of pre-engraftment COVID-19...
# 2  The impact of COVID-19 on oncology professiona...
# 3  ICU admission and mortality classifiers for CO...
# 4  Clinical evaluation of nasopharyngeal  midturb...
# 5  Safer in care  A pandemic-tested model of inte...
# 6  The effect of Covid-19 in digital media use of...
# 7  Scanning the RBD-ACE2 molecular interactions i...
# 8  Implications of SARS-CoV-2 infection on the cl...
# 9  Merbromin is a mixed-type inhibitor of 3-chyom...
#
#                                             abstract  \
# 0  This article summarizes the experiences of COV...
# 1  Coronavirus disease 2019  COVID-19   caused by...
# 2  BACKGROUND  COVID-19 has had a significant imp...
# 3  The coronavirus disease 2019  COVID-19  which ...
# 4  In the setting of supply chain shortages of na...
# 5  BACKGROUND  Rural  poor  persons with HIV  PWH...
# 6  BACKGROUND  Covid-19 pandemic has boosted digi...
# 7  The emergence of new SARS-CoV-2 variants poses...
# 8  BACKGROUND  The current coronavirus pandemic  ...
# 9  3-chyomotrypsin like protease  3CLpro  has bee...
#
#                                         url  topic
# 0  https://pubmed.ncbi.nlm.nih.gov/35008137     91
# 1  https://pubmed.ncbi.nlm.nih.gov/35008104     -1
# 2  https://pubmed.ncbi.nlm.nih.gov/35007996    106
# 3  https://pubmed.ncbi.nlm.nih.gov/35007991     88
# 4  https://pubmed.ncbi.nlm.nih.gov/35007959     -1
# 5  https://pubmed.ncbi.nlm.nih.gov/35007957    119
# 6  https://pubmed.ncbi.nlm.nih.gov/35007925     -1
# 7  https://pubmed.ncbi.nlm.nih.gov/35007846     -1
# 8  https://pubmed.ncbi.nlm.nih.gov/35007842     -1
# 9  https://pubmed.ncbi.nlm.nih.gov/35007835      6

# %%
topic_labels=(topic_model.generate_topic_labels())
topic_labels
# Out:
# ['-1_the_of_covid',
#  '0_telemedicine_telehealth_satisfaction',
#  '1_mental_health_psychiatric',
#  '2_respiratory_oxygen_ventilation',
#  '3_drug_treatment_potential',
#  '4_child_children_parents',
#  '5_sars_cov_transmission',
#  '6_protease_inhibitors_main',
#  '7_variants_sars_cov',
#  '8_online_learning_education',
#  '9_antibodies_igg_neutralizing',
#  '10_spike_ace2_protein',
#  '11_media_twitter_social',
#  '12_prognosis_reactive_meta',
#  '13_masks_mask_face',
#  '14_nurses_nursing_nurse',
#  '15_vaccine_vaccination_2021',
#  '16_pregnant_pregnancy_women',
#  '17_graphene_detection_biosensor',
#  '18_modeling_mathematical_epidemic',
#  '19_vaccine_willingness_acceptance',
#  '20_images_ray_chest',
#  '21_dental_oral_dentistry',
#  '22_neurological_brain_palsy',
#  '23_cytokine_neutrophil_storm',
#  '24_machine_artificial_intelligence',
#  '25_sleep_quality_insomnia',
#  '26_mobility_transport_transportation',
#  '27_respiratory_syndrome_acute',
#  '28_pollution_air_pm2',
#  '29_students_university_college',
#  '30_lessons_emergency_response',
#  '31_mortality_excess_deaths',
#  '32_sequencing_genome_mutations',
#  '33_transplant_recipients_kidney',
#  '34_multisystem_inflammatory_syndrome',
#  '35_workers_healthcare_frontline',
#  '36_saudi_arabia_pakistan',
#  '37_trauma_hip_fracture',
#  '38_pediatric_children_pediatrics',
#  '39_cell_cells_memory',
#  '40_2019_coronavirus_disease',
#  '41_retinal_eye_ocular',
#  '42_digital_record_data',
#  '43_thrombocytopenia_thrombosis_thrombotic',
#  '44_eating_nutritional_diet',
#  '45_food_insecurity_security',
#  '46_surgery_surgical_elective',
#  '47_children_cov_sars',
#  '48_bowel_inflammatory_microbiota',
#  '49_postpartum_women_pregnant',
#  '50_bnt162b2_mrna_vaccine',
#  '51_mucormycosis_rhino_orbital',
#  '52_pcr_rt_pooled',
#  '53_pneumonia_classification_pneumonias',
#  '54_china_epidemiological_control',
#  '55_knowledge_attitude_practices',
#  '56_india_blood_tertiary',
#  '57_physical_activity_exercise',
#  '58_vaccines_delta_recombinant',
#  '59_aspergillosis_invasive_fungal',
#  '60_vitamin_d3_status',
#  '61_loneliness_older_isolation',
#  '62_thrombosis_venous_thromboembolism',
#  '63_myocarditis_myopericarditis_mrna',
#  '64_skin_psoriasis_androgenetic',
#  '65_dementia_caregivers_support',
#  '66_nanoparticles_delivery_nanoparticle',
#  '67_virtual_reality_skills',
#  '68_sclerosis_multiple_modifying',
#  '69_hearing_voice_audiology',
#  '70_pregnancy_maternal_fetal',
#  '71_stress_uncertainty_coping',
#  '72_monitoring_wearable_temperature',
#  '73_remdesivir_antiviral_synthesis',
#  '74_cancer_colorectal_impact',
#  '75_diabetes_type_mellitus',
#  '76_transplant_recipients_kidney',
#  '77_stock_market_oil',
#  '78_omicron_variant_529',
#  '79_bioinformatics_atlas_drug',
#  '80_angiotensin_converting_enzyme',
#  '81_community_religious_sense',
#  '82_bnt162b2_mrna_humoral',
#  '83_opioid_poison_buprenorphine',
#  '84_kidney_injury_acute',
#  '85_host_replication_viral',
#  '86_myocardial_infarction_elevation',
#  '87_health_policy_public',
#  '88_intensive_critically_ill',
#  '89_traumatic_posttraumatic_ptsd',
#  '90_school_closures_schools',
#  '91_antibody_monoclonal_antibodies',
#  '92_density_variants_cov',
#  '93_tourism_customer_consumer',
#  '94_alcohol_consumption_drinking',
#  '95_nursing_students_nurses',
#  '96_vaccines_mrna_anaphylaxis',
#  '97_asthma_allergic_inhaled',
#  '98_burnout_staff_stress',
#  '99_chile_mexico_prison',
#  '100_china_vaccine_uptake',
#  '101_football_professional_athletes',
#  '102_scale_psychometric_anxiety',
#  '103_racial_disparities_ethnic',
#  '104_erectile_semen_men',
#  '105_hesitancy_vaccine_ethnicity',
#  '106_resilience_healthcare_lessons',
#  '107_tuberculosis_tb_endemic',
#  '108_cells_lung_epithelial',
#  '109_mortality_hospitalized_predictors',
#  '110_liver_cirrhosis_chronic',
#  '111_porous_surfaces_biodegradable',
#  '112_violence_intimate_partner',
#  '113_ultrasound_lung_pneumonia',
#  '114_adherence_guidelines_compliance',
#  '115_qpcr_rt_pcr',
#  '116_breast_cancer_hispanic',
#  '117_chest_ct_tomography',
#  '118_cost_screening_kenya',
#  '119_hiv_services_adherence',
#  '120_suicidal_suicide_ideation',
#  '121_arabia_saudi_hesitancy',
#  '122_rehabilitation_cardiac_physiotherapists',
#  '123_cardiovascular_heart_prognosis',
#  '124_plasma_convalescent_controlled',
#  '125_mathematics_education_mathematical',
#  '126_pneumothorax_spontaneous_pneumomediastinum',
#  '127_tracing_contact_san',
#  '128_substance_use_addictive',
#  '129_cats_dogs_domestic',
#  '130_saliva_salivary_swabs',
#  '131_stroke_ischemic_mena',
#  '132_smoking_tobacco_smokers',
#  '133_france_vaccination_spain',
#  '134_pain_fibromyalgia_chronic',
#  '135_wastewater_surveillance_sewage',
#  '136_omicron_529_neutralizing',
#  '137_weight_obesity_lifestyle',
#  '138_hemodialysis_dialysis_haemodialysis',
#  '139_virtual_diabetes_oncology',
#  '140_isothermal_amplification_loop',
#  '141_resuscitation_cardiopulmonary_cardiac',
#  '142_hiv_people_living',
#  '143_multisystem_inflammatory_syndrome',
#  '144_chadox1_ncov_azd1222',
#  '145_parkinson_motor_feasibility',
#  '146_corticosteroids_corticosteroid_systemic',
#  '147_internet_addiction_adolescents',
#  '148_immune_sex_aging',
#  '149_capacity_icu_simulation',
#  '150_cystic_fibrosis_telehealth',
#  '151_influenza_united_kingdom',
#  '152_urban_cities_green',
#  '153_depression_anxiety_probable',
#  '154_disinfection_surfaces_bacterial',
#  '155_dementia_cognitive_20',
#  '156_extracorporeal_oxygenation_membrane',
#  '157_tocilizumab_pneumonia_steroid',
#  '158_tracheostomy_tracheal_timing',
#  '159_reproductive_sexual_sex',
#  '160_pharmacists_pharmacist_pharmacy',
#  '161_telerehabilitation_effectiveness_feasibility',
#  '162_fatigue_carnitine_mendelian',
#  '163_palliative_care_end',
#  '164_axillary_pet_fdg',
#  '165_heart_failure_cardiovascular',
#  '166_arthritis_rheumatoid_rheumatic',
#  '167_industries_economies_trade',
#  '168_mesenchymal_stem_cells',
#  '169_hypertension_pressure_control',
#  '170_mrna_revolution_development',
#  '171_hand_hygiene_hospitals',
#  '172_pandemics_science_climate',
#  '173_embolism_pulmonary_dimers',
#  '174_deep_learning_entity',
#  '175_distancing_social_kalman',
#  '176_employment_benefits_unemployment',
#  '177_coagulopathy_fibrinogen_coagulation',
#  '178_metabolic_adiposity_lipid',
#  '179_migrant_refugees_migrants']

# %%
topic_mapping = {i: label for i, label in enumerate(topic_labels, start=-1)}
topic_mapping
# Out:
# {-1: '-1_the_of_covid',
#  0: '0_telemedicine_telehealth_satisfaction',
#  1: '1_mental_health_psychiatric',
#  2: '2_respiratory_oxygen_ventilation',
#  3: '3_drug_treatment_potential',
#  4: '4_child_children_parents',
#  5: '5_sars_cov_transmission',
#  6: '6_protease_inhibitors_main',
#  7: '7_variants_sars_cov',
#  8: '8_online_learning_education',
#  9: '9_antibodies_igg_neutralizing',
#  10: '10_spike_ace2_protein',
#  11: '11_media_twitter_social',
#  12: '12_prognosis_reactive_meta',
#  13: '13_masks_mask_face',
#  14: '14_nurses_nursing_nurse',
#  15: '15_vaccine_vaccination_2021',
#  16: '16_pregnant_pregnancy_women',
#  17: '17_graphene_detection_biosensor',
#  18: '18_modeling_mathematical_epidemic',
#  19: '19_vaccine_willingness_acceptance',
#  20: '20_images_ray_chest',
#  21: '21_dental_oral_dentistry',
#  22: '22_neurological_brain_palsy',
#  23: '23_cytokine_neutrophil_storm',
#  24: '24_machine_artificial_intelligence',
#  25: '25_sleep_quality_insomnia',
#  26: '26_mobility_transport_transportation',
#  27: '27_respiratory_syndrome_acute',
#  28: '28_pollution_air_pm2',
#  29: '29_students_university_college',
#  30: '30_lessons_emergency_response',
#  31: '31_mortality_excess_deaths',
#  32: '32_sequencing_genome_mutations',
#  33: '33_transplant_recipients_kidney',
#  34: '34_multisystem_inflammatory_syndrome',
#  35: '35_workers_healthcare_frontline',
#  36: '36_saudi_arabia_pakistan',
#  37: '37_trauma_hip_fracture',
#  38: '38_pediatric_children_pediatrics',
#  39: '39_cell_cells_memory',
#  40: '40_2019_coronavirus_disease',
#  41: '41_retinal_eye_ocular',
#  42: '42_digital_record_data',
#  43: '43_thrombocytopenia_thrombosis_thrombotic',
#  44: '44_eating_nutritional_diet',
#  45: '45_food_insecurity_security',
#  46: '46_surgery_surgical_elective',
#  47: '47_children_cov_sars',
#  48: '48_bowel_inflammatory_microbiota',
#  49: '49_postpartum_women_pregnant',
#  50: '50_bnt162b2_mrna_vaccine',
#  51: '51_mucormycosis_rhino_orbital',
#  52: '52_pcr_rt_pooled',
#  53: '53_pneumonia_classification_pneumonias',
#  54: '54_china_epidemiological_control',
#  55: '55_knowledge_attitude_practices',
#  56: '56_india_blood_tertiary',
#  57: '57_physical_activity_exercise',
#  58: '58_vaccines_delta_recombinant',
#  59: '59_aspergillosis_invasive_fungal',
#  60: '60_vitamin_d3_status',
#  61: '61_loneliness_older_isolation',
#  62: '62_thrombosis_venous_thromboembolism',
#  63: '63_myocarditis_myopericarditis_mrna',
#  64: '64_skin_psoriasis_androgenetic',
#  65: '65_dementia_caregivers_support',
#  66: '66_nanoparticles_delivery_nanoparticle',
#  67: '67_virtual_reality_skills',
#  68: '68_sclerosis_multiple_modifying',
#  69: '69_hearing_voice_audiology',
#  70: '70_pregnancy_maternal_fetal',
#  71: '71_stress_uncertainty_coping',
#  72: '72_monitoring_wearable_temperature',
#  73: '73_remdesivir_antiviral_synthesis',
#  74: '74_cancer_colorectal_impact',
#  75: '75_diabetes_type_mellitus',
#  76: '76_transplant_recipients_kidney',
#  77: '77_stock_market_oil',
#  78: '78_omicron_variant_529',
#  79: '79_bioinformatics_atlas_drug',
#  80: '80_angiotensin_converting_enzyme',
#  81: '81_community_religious_sense',
#  82: '82_bnt162b2_mrna_humoral',
#  83: '83_opioid_poison_buprenorphine',
#  84: '84_kidney_injury_acute',
#  85: '85_host_replication_viral',
#  86: '86_myocardial_infarction_elevation',
#  87: '87_health_policy_public',
#  88: '88_intensive_critically_ill',
#  89: '89_traumatic_posttraumatic_ptsd',
#  90: '90_school_closures_schools',
#  91: '91_antibody_monoclonal_antibodies',
#  92: '92_density_variants_cov',
#  93: '93_tourism_customer_consumer',
#  94: '94_alcohol_consumption_drinking',
#  95: '95_nursing_students_nurses',
#  96: '96_vaccines_mrna_anaphylaxis',
#  97: '97_asthma_allergic_inhaled',
#  98: '98_burnout_staff_stress',
#  99: '99_chile_mexico_prison',
#  100: '100_china_vaccine_uptake',
#  101: '101_football_professional_athletes',
#  102: '102_scale_psychometric_anxiety',
#  103: '103_racial_disparities_ethnic',
#  104: '104_erectile_semen_men',
#  105: '105_hesitancy_vaccine_ethnicity',
#  106: '106_resilience_healthcare_lessons',
#  107: '107_tuberculosis_tb_endemic',
#  108: '108_cells_lung_epithelial',
#  109: '109_mortality_hospitalized_predictors',
#  110: '110_liver_cirrhosis_chronic',
#  111: '111_porous_surfaces_biodegradable',
#  112: '112_violence_intimate_partner',
#  113: '113_ultrasound_lung_pneumonia',
#  114: '114_adherence_guidelines_compliance',
#  115: '115_qpcr_rt_pcr',
#  116: '116_breast_cancer_hispanic',
#  117: '117_chest_ct_tomography',
#  118: '118_cost_screening_kenya',
#  119: '119_hiv_services_adherence',
#  120: '120_suicidal_suicide_ideation',
#  121: '121_arabia_saudi_hesitancy',
#  122: '122_rehabilitation_cardiac_physiotherapists',
#  123: '123_cardiovascular_heart_prognosis',
#  124: '124_plasma_convalescent_controlled',
#  125: '125_mathematics_education_mathematical',
#  126: '126_pneumothorax_spontaneous_pneumomediastinum',
#  127: '127_tracing_contact_san',
#  128: '128_substance_use_addictive',
#  129: '129_cats_dogs_domestic',
#  130: '130_saliva_salivary_swabs',
#  131: '131_stroke_ischemic_mena',
#  132: '132_smoking_tobacco_smokers',
#  133: '133_france_vaccination_spain',
#  134: '134_pain_fibromyalgia_chronic',
#  135: '135_wastewater_surveillance_sewage',
#  136: '136_omicron_529_neutralizing',
#  137: '137_weight_obesity_lifestyle',
#  138: '138_hemodialysis_dialysis_haemodialysis',
#  139: '139_virtual_diabetes_oncology',
#  140: '140_isothermal_amplification_loop',
#  141: '141_resuscitation_cardiopulmonary_cardiac',
#  142: '142_hiv_people_living',
#  143: '143_multisystem_inflammatory_syndrome',
#  144: '144_chadox1_ncov_azd1222',
#  145: '145_parkinson_motor_feasibility',
#  146: '146_corticosteroids_corticosteroid_systemic',
#  147: '147_internet_addiction_adolescents',
#  148: '148_immune_sex_aging',
#  149: '149_capacity_icu_simulation',
#  150: '150_cystic_fibrosis_telehealth',
#  151: '151_influenza_united_kingdom',
#  152: '152_urban_cities_green',
#  153: '153_depression_anxiety_probable',
#  154: '154_disinfection_surfaces_bacterial',
#  155: '155_dementia_cognitive_20',
#  156: '156_extracorporeal_oxygenation_membrane',
#  157: '157_tocilizumab_pneumonia_steroid',
#  158: '158_tracheostomy_tracheal_timing',
#  159: '159_reproductive_sexual_sex',
#  160: '160_pharmacists_pharmacist_pharmacy',
#  161: '161_telerehabilitation_effectiveness_feasibility',
#  162: '162_fatigue_carnitine_mendelian',
#  163: '163_palliative_care_end',
#  164: '164_axillary_pet_fdg',
#  165: '165_heart_failure_cardiovascular',
#  166: '166_arthritis_rheumatoid_rheumatic',
#  167: '167_industries_economies_trade',
#  168: '168_mesenchymal_stem_cells',
#  169: '169_hypertension_pressure_control',
#  170: '170_mrna_revolution_development',
#  171: '171_hand_hygiene_hospitals',
#  172: '172_pandemics_science_climate',
#  173: '173_embolism_pulmonary_dimers',
#  174: '174_deep_learning_entity',
#  175: '175_distancing_social_kalman',
#  176: '176_employment_benefits_unemployment',
#  177: '177_coagulopathy_fibrinogen_coagulation',
#  178: '178_metabolic_adiposity_lipid',
#  179: '179_migrant_refugees_migrants'}

# %%
import numpy as np
# Replace -1 (Outliers) temporarily with NaN to handle missing labels
df["topic_name"] = df["topic"].replace(-1, np.nan)


# Map topic_labels directly to the topic column
df["topic_name"] = df["topic_name"].map(pd.Series(topic_mapping))

df.tail(10)
# Out:
#                                                   title  \
# 9990  Factors associated with early receipt of COVID...
# 9991  Aerosol tracer testing in Boeing 767 and 777 a...
# 9992  Cumulative burden of non-communicable diseases...
# 9993  Preoperative and Postoperative Opioid Prescrip...
# 9994  Hypersensitivity Reactions to Vaccines  Curren...
# 9995  Rooming-in  Breastfeeding and Neonatal Follow-...
# 9996  Acute Retinal Necrosis from Reactivation of Va...
# 9997  Acute Abducens Nerve Palsy Following the Secon...
# 9998  Planning and Implementing the Protocol for Psy...
# 9999  Prolonged corrected QT interval in hospitalize...
#
#                                                abstract  \
# 9990  BACKGROUND  We aimed to determine factors inde...
# 9991  The COVID-19 pandemic has reintroduced questio...
# 9992  There continue to be conflicting data regardin...
# 9993  The United States is facing an opioid epidemic...
# 9994  The first reports of hypersensitivity reaction...
# 9995  INTRODUCTION  Due to growing evidence suggesti...
# 9996  PURPOSE  To report a case of acute retinal nec...
# 9997  The authors report the case of an otherwise he...
# 9998  The present study aims to plan the protocol fo...
# 9999  OBJECTIVE  To evaluate the association of a pr...
#
#                                            url  topic  \
# 9990  https://pubmed.ncbi.nlm.nih.gov/34851970     15
# 9991  https://pubmed.ncbi.nlm.nih.gov/34851965     -1
# 9992  https://pubmed.ncbi.nlm.nih.gov/34851963    119
# 9993  https://pubmed.ncbi.nlm.nih.gov/34851880     37
# 9994  https://pubmed.ncbi.nlm.nih.gov/34851819      7
# 9995  https://pubmed.ncbi.nlm.nih.gov/34851815     -1
# 9996  https://pubmed.ncbi.nlm.nih.gov/34851795     -1
# 9997  https://pubmed.ncbi.nlm.nih.gov/34851785     22
# 9998  https://pubmed.ncbi.nlm.nih.gov/34851781     35
# 9999  https://pubmed.ncbi.nlm.nih.gov/34851769     40
#
#                            topic_name
# 9990      15_vaccine_vaccination_2021
# 9991                              NaN
# 9992       119_hiv_services_adherence
# 9993           37_trauma_hip_fracture
# 9994              7_variants_sars_cov
# 9995                              NaN
# 9996                              NaN
# 9997      22_neurological_brain_palsy
# 9998  35_workers_healthcare_frontline
# 9999      40_2019_coronavirus_disease

# %%
# Fill NaN values with "Outlier" for -1 topics
df["topic_name"].fillna("Outlier", inplace=True)

# %%
df.tail(10)
# Out:
#                                                   title  \
# 9990  Factors associated with early receipt of COVID...
# 9991  Aerosol tracer testing in Boeing 767 and 777 a...
# 9992  Cumulative burden of non-communicable diseases...
# 9993  Preoperative and Postoperative Opioid Prescrip...
# 9994  Hypersensitivity Reactions to Vaccines  Curren...
# 9995  Rooming-in  Breastfeeding and Neonatal Follow-...
# 9996  Acute Retinal Necrosis from Reactivation of Va...
# 9997  Acute Abducens Nerve Palsy Following the Secon...
# 9998  Planning and Implementing the Protocol for Psy...
# 9999  Prolonged corrected QT interval in hospitalize...
#
#                                                abstract  \
# 9990  BACKGROUND  We aimed to determine factors inde...
# 9991  The COVID-19 pandemic has reintroduced questio...
# 9992  There continue to be conflicting data regardin...
# 9993  The United States is facing an opioid epidemic...
# 9994  The first reports of hypersensitivity reaction...
# 9995  INTRODUCTION  Due to growing evidence suggesti...
# 9996  PURPOSE  To report a case of acute retinal nec...
# 9997  The authors report the case of an otherwise he...
# 9998  The present study aims to plan the protocol fo...
# 9999  OBJECTIVE  To evaluate the association of a pr...
#
#                                            url  topic  \
# 9990  https://pubmed.ncbi.nlm.nih.gov/34851970     15
# 9991  https://pubmed.ncbi.nlm.nih.gov/34851965     -1
# 9992  https://pubmed.ncbi.nlm.nih.gov/34851963    119
# 9993  https://pubmed.ncbi.nlm.nih.gov/34851880     37
# 9994  https://pubmed.ncbi.nlm.nih.gov/34851819      7
# 9995  https://pubmed.ncbi.nlm.nih.gov/34851815     -1
# 9996  https://pubmed.ncbi.nlm.nih.gov/34851795     -1
# 9997  https://pubmed.ncbi.nlm.nih.gov/34851785     22
# 9998  https://pubmed.ncbi.nlm.nih.gov/34851781     35
# 9999  https://pubmed.ncbi.nlm.nih.gov/34851769     40
#
#                            topic_name
# 9990      15_vaccine_vaccination_2021
# 9991                          Outlier
# 9992       119_hiv_services_adherence
# 9993           37_trauma_hip_fracture
# 9994              7_variants_sars_cov
# 9995                          Outlier
# 9996                          Outlier
# 9997      22_neurological_brain_palsy
# 9998  35_workers_healthcare_frontline
# 9999      40_2019_coronavirus_disease

# %%
df_changes = df[df['topic'] == 19]

# %%
df_changes
# Out:
#                                                   title  \
# 417   Personal willingness to receive a Covid-19 vac...
# 673         The myth of vaccination and autism spectrum
# 691   Factors and Reasons Associated with Low COVID-...
# 976   COVID-19 vaccine acceptance and hesitancy amon...
# 1538  Attitudes towards vaccines and intention to va...
# ...                                                 ...
# 9216  Relationship between mask wearing  testing  an...
# 9289  Individual factors influencing COVID-19 vaccin...
# 9678  Measuring vaccination willingness in response ...
# 9838  COVID-19 Vaccine Concerns and Acceptability by...
# 9883  COVID-19 Vaccine Acceptance  Beliefs and Barri...
#
#                                                abstract  \
# 417   High levels of vaccine hesitancy are an obstac...
# 673   BACKGROUND  Among all of the studied potential...
# 691   INTRODUCTION  The inability to achieve high CO...
# 976   BACKGROUND  We assessed willingness to accept ...
# 1538  OBJECTIVE  To examine SARS-CoV-2 vaccine confi...
# ...                                                 ...
# 9216  BACKGROUND  Mask wearing mitigates the spread ...
# 9289  BACKGROUND  A year after the start of the COVI...
# 9678  The pandemic COVID-19 is continued to the mass...
# 9838  INTRODUCTION  We need to understand the contin...
# 9883  Introduction  COVID-19 was declared a pandemic...
#
#                                            url  topic  \
# 417   https://pubmed.ncbi.nlm.nih.gov/35001533     19
# 673   https://pubmed.ncbi.nlm.nih.gov/34996019     19
# 691   https://pubmed.ncbi.nlm.nih.gov/34995722     19
# 976   https://pubmed.ncbi.nlm.nih.gov/34990311     19
# 1538  https://pubmed.ncbi.nlm.nih.gov/34980631     19
# ...                                        ...    ...
# 9216  https://pubmed.ncbi.nlm.nih.gov/34865166     19
# 9289  https://pubmed.ncbi.nlm.nih.gov/34863621     19
# 9678  https://pubmed.ncbi.nlm.nih.gov/34856879     19
# 9838  https://pubmed.ncbi.nlm.nih.gov/34854328     19
# 9883  https://pubmed.ncbi.nlm.nih.gov/34853514     19
#
#                              topic_name
# 417   19_vaccine_willingness_acceptance
# 673   19_vaccine_willingness_acceptance
# 691   19_vaccine_willingness_acceptance
# 976   19_vaccine_willingness_acceptance
# 1538  19_vaccine_willingness_acceptance
# ...                                 ...
# 9216  19_vaccine_willingness_acceptance
# 9289  19_vaccine_willingness_acceptance
# 9678  19_vaccine_willingness_acceptance
# 9838  19_vaccine_willingness_acceptance
# 9883  19_vaccine_willingness_acceptance
#
# [67 rows x 5 columns]
